# %% [markdown]
# # Toronto Neighbourhoods and Postal Codes

# %%
import pandas as pd
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page

# %%
#!conda install -c conda-forge folium=0.5.0 --yes
import folium # map rendering library

# %% [markdown]
# This step define a function to geolocate and address or postal code

# %%
import geocoder

# %%
def geolocate(address):
    lat_lng_coords = None
    while(lat_lng_coords is None):
      g = geocoder.arcgis(address)
      lat_lng_coords = g.latlng
    latitude = lat_lng_coords[0]
    longitude = lat_lng_coords[1]
    return latitude,longitude

# %% [markdown]
# URL where Toronto's Postal Codes are taken

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

# %%
data  = requests.get(url).text

# %%
soup = BeautifulSoup(data,"html5lib")  # create a soup object using the variable 'data'

# %% [markdown]
# Using the read_html method to extract the tables from the URL

# %%
dataframe_list = pd.read_html(url, flavor='bs4')

# %% [markdown]
# ## Toronto's Postal Code table

# %%
postal_codes = dataframe_list[0]
postal_codes
# Out:
#                                                     0  \
# 0                                     M1ANot assigned
# 1                     M1BScarborough(Malvern / Rouge)
# 2   M1CScarborough(Rouge Hill / Port Union / Highl...
# 3   M1EScarborough(Guildwood / Morningside / West ...
# 4                              M1GScarborough(Woburn)
# 5                           M1HScarborough(Cedarbrae)
# 6                 M1JScarborough(Scarborough Village)
# 7   M1KScarborough(Kennedy Park / Ionview / East B...
# 8   M1LScarborough(Golden Mile / Clairlea / Oakridge)
# 9   M1MScarborough(Cliffside / Cliffcrest / Scarbo...
# 10       M1NScarborough(Birch Cliff / Cliffside West)
# 11  M1PScarborough(Dorset Park / Wexford Heights /...
# 12                 M1RScarborough(Wexford / Maryvale)
# 13                          M1SScarborough(Agincourt)
# 14  M1TScarborough(Clarks Corners / Tam O'Shanter ...
# 15  M1VScarborough(Milliken / Agincourt North / St...
# 16     M1WScarborough(Steeles West / L'Amoreaux West)
# 17                        M1XScarborough(Upper Rouge)
# 18                                    M1YNot assigned
# 19                                    M1ZNot assigned
#
#                                                 1  \
# 0                                 M2ANot assigned
# 1                                 M2BNot assigned
# 2                                 M2CNot assigned
# 3                                 M2ENot assigned
# 4                                 M2GNot assigned
# 5                M2HNorth York(Hillcrest Village)
# 6   M2JNorth York(Fairview / Henry Farm / Oriole)
# 7                  M2KNorth York(Bayview Village)
# 8        M2LNorth York(York Mills / Silver Hills)
# 9         M2MNorth York(Willowdale / Newtonbrook)
# 10                 M2NNorth York(Willowdale)South
# 11                 M2PNorth York(York Mills West)
# 12                  M2RNorth York(Willowdale)West
# 13                                M2SNot assigned
# 14                                M2TNot assigned
# 15                                M2VNot assigned
# 16                                M2WNot assigned
# 17                                M2XNot assigned
# 18                                M2YNot assigned
# 19                                M2ZNot assigned
#
#                                                     2  \
# 0                            M3ANorth York(Parkwoods)
# 1                       M3BNorth York(Don Mills)North
# 2      M3CNorth York(Don Mills)South(Flemingdon Park)
# 3                                     M3ENot assigned
# 4                                     M3GNot assigned
# 5   M3HNorth York(Bathurst Manor / Wilson Heights ...
# 6     M3JNorth York(Northwood Park / York University)
# 7          M3KNorth York(Downsview)East (CFB Toronto)
# 8                        M3LNorth York(Downsview)West
# 9                     M3MNorth York(Downsview)Central
# 10                  M3NNorth York(Downsview)Northwest
# 11                                    M3PNot assigned
# 12                                    M3RNot assigned
# 13                                    M3SNot assigned
# 14                                    M3TNot assigned
# 15                                    M3VNot assigned
# 16                                    M3WNot assigned
# 17                                    M3XNot assigned
# 18                                    M3YNot assigned
# 19                                    M3ZNot assigned
#
#                                                     3  \
# 0                     M4ANorth York(Victoria Village)
# 1      M4BEast York(Parkview Hill / Woodbine Gardens)
# 2                      M4CEast York(Woodbine Heights)
# 3                        M4EEast Toronto(The Beaches)
# 4                               M4GEast York(Leaside)
# 5                      M4HEast York(Thorncliffe Park)
# 6         M4JEast YorkEast Toronto(The Danforth East)
# 7      M4KEast Toronto(The Danforth West / Riverdale)
# 8    M4LEast Toronto(India Bazaar / The Beaches West)
# 9                    M4MEast Toronto(Studio District)
# 10                  M4NCentral Toronto(Lawrence Park)
# 11               M4PCentral Toronto(Davisville North)
# 12             M4RCentral Toronto(North Toronto West)
# 13                     M4SCentral Toronto(Davisville)
# 14   M4TCentral Toronto(Moore Park / Summerhill East)
# 15  M4VCentral Toronto(Summerhill West / Rathnelly...
# 16                      M4WDowntown Toronto(Rosedale)
# 17  M4XDowntown Toronto(St. James Town / Cabbagetown)
# 18          M4YDowntown Toronto(Church and Wellesley)
# 19                                    M4ZNot assigned
#
#                                                     4  \
# 0     M5ADowntown Toronto(Regent Park / Harbourfront)
# 1       M5BDowntown Toronto(Garden District, Ryerson)
# 2                 M5CDowntown Toronto(St. James Town)
# 3                    M5EDowntown Toronto(Berczy Park)
# 4             M5GDowntown Toronto(Central Bay Street)
# 5     M5HDowntown Toronto(Richmond / Adelaide / King)
# 6   M5JDowntown Toronto(Harbourfront East / Union ...
# 7   M5KDowntown Toronto(Toronto Dominion Centre / ...
# 8   M5LDowntown Toronto(Commerce Court / Victoria ...
# 9   M5MNorth York(Bedford Park / Lawrence Manor East)
# 10                       M5NCentral Toronto(Roselawn)
# 11       M5PCentral Toronto(Forest Hill North & West)
# 12  M5RCentral Toronto(The Annex / North Midtown /...
# 13  M5SDowntown Toronto(University of Toronto / Ha...
# 14  M5TDowntown Toronto(Kensington Market / Chinat...
# 15  M5VDowntown Toronto(CN Tower / King and Spadin...
# 16  M5WDowntown TorontoStn A PO Boxes25 The Esplan...
# 17  M5XDowntown Toronto(First Canadian Place / Und...
# 18                                    M5YNot assigned
# 19                                    M5ZNot assigned
#
#                                                     5  \
# 0    M6ANorth York(Lawrence Manor / Lawrence Heights)
# 1                            M6BNorth York(Glencairn)
# 2                         M6CYork(Humewood-Cedarvale)
# 3                        M6EYork(Caledonia-Fairbanks)
# 4                       M6GDowntown Toronto(Christie)
# 5      M6HWest Toronto(Dufferin / Dovercourt Village)
# 6          M6JWest Toronto(Little Portugal / Trinity)
# 7   M6KWest Toronto(Brockton / Parkdale Village / ...
# 8   M6LNorth York(North Park / Maple Leaf Park / U...
# 9   M6MYork(Del Ray / Mount Dennis / Keelsdale and...
# 10            M6NYork(Runnymede / The Junction North)
# 11    M6PWest Toronto(High Park / The Junction South)
# 12           M6RWest Toronto(Parkdale / Roncesvalles)
# 13               M6SWest Toronto(Runnymede / Swansea)
# 14                                    M6TNot assigned
# 15                                    M6VNot assigned
# 16                                    M6WNot assigned
# 17                                    M6XNot assigned
# 18                                    M6YNot assigned
# 19                                    M6ZNot assigned
#
#                                                     6  \
# 0      M7AQueen's Park(Ontario Provincial Government)
# 1                                     M7BNot assigned
# 2                                     M7CNot assigned
# 3                                     M7ENot assigned
# 4                                     M7GNot assigned
# 5                                     M7HNot assigned
# 6                                     M7JNot assigned
# 7                                     M7KNot assigned
# 8                                     M7LNot assigned
# 9                                     M7MNot assigned
# 10                                    M7NNot assigned
# 11                                    M7PNot assigned
# 12  M7RMississaugaCanada Post Gateway Processing C...
# 13                                    M7SNot assigned
# 14                                    M7TNot assigned
# 15                                    M7VNot assigned
# 16                                    M7WNot assigned
# 17                                    M7XNot assigned
# 18  M7YEast TorontoBusiness reply mail Processing ...
# 19                                    M7ZNot assigned
#
#                                                     7  \
# 0                                     M8ANot assigned
# 1                                     M8BNot assigned
# 2                                     M8CNot assigned
# 3                                     M8ENot assigned
# 4                                     M8GNot assigned
# 5                                     M8HNot assigned
# 6                                     M8JNot assigned
# 7                                     M8KNot assigned
# 8                                     M8LNot assigned
# 9                                     M8MNot assigned
# 10                                    M8NNot assigned
# 11                                    M8PNot assigned
# 12                                    M8RNot assigned
# 13                                    M8SNot assigned
# 14                                    M8TNot assigned
# 15  M8VEtobicoke(New Toronto / Mimico South / Humb...
# 16              M8WEtobicoke(Alderwood / Long Branch)
# 17  M8XEtobicoke(The Kingsway / Montgomery Road / ...
# 18  M8YEtobicoke(Old Mill South / King's Mill Park...
# 19  M8ZEtobicoke(Mimico NW / The Queensway West / ...
#
#                                                     8
# 0                      M9AEtobicoke(Islington Avenue)
# 1   M9BEtobicoke(West Deane Park / Princess Garden...
# 2   M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 3                                     M9ENot assigned
# 4                                     M9GNot assigned
# 5                                     M9HNot assigned
# 6                                     M9JNot assigned
# 7                                     M9KNot assigned
# 8                        M9LNorth York(Humber Summit)
# 9                    M9MNorth York(Humberlea / Emery)
# 10                                    M9NYork(Weston)
# 11                            M9PEtobicoke(Westmount)
# 12  M9REtobicoke(Kingsview Village / St. Phillips ...
# 13                                    M9SNot assigned
# 14                                    M9TNot assigned
# 15  M9VEtobicoke(South Steeles / Silverstone / Hum...
# 16  M9WEtobicokeNorthwest(Clairville / Humberwood ...
# 17                                    M9XNot assigned
# 18                                    M9YNot assigned
# 19                                    M9ZNot assigned

# %% [markdown]
# Exploring the data of Postal Code to select Boroughs and Neighbourhoods

# %%
postal_codes.shape
# Out:
# (20, 9)

# %%
postal_codes.iloc[0,0][3:17] # Exploring how to identify the Postal Code assigment
# Out:
# 'Not assigned'

# %%
Toronto = pd.DataFrame(columns = ['postal_code', 'borough', 'neighbourhoods']) # Create Dataframe for data
Toronto
# Out:
# Empty DataFrame
# Columns: [postal_code, borough, neighbourhoods]
# Index: []

# %% [markdown]
# The following code , extract borough and neighbourhood info from the postal code table - includes to change separator of neighbourhoods with ","

# %%
x = 0
borough=''
neighbour=''
complete = True
for index, row in postal_codes.iterrows():
    for region in list(row):
        Toronto.at[x,'postal_code'] = region[0:3]
        for char in region[3:]:
            if (char != '(') & complete:
                borough = borough + char
            else:
                complete = False
                if char != ')':
                    if char != '(':
                        neighbour = neighbour+char
        Toronto.at[x,'borough'] = borough
        Toronto.at[x,'neighbourhoods'] = neighbour.replace('/',',')
        neighbour=''
        borough=''
        complete=True
        x=x+1

# %% [markdown]
# ## Segmenting and cleanning the data to identify values to be corrected or eliminated

# %%
Toronto.borough.value_counts()
# Out:
# Not assigned                                                    77
# North York                                                      24
# Scarborough                                                     17
# Downtown Toronto                                                17
# Etobicoke                                                       11
# Central Toronto                                                  9
# West Toronto                                                     6
# York                                                             5
# East Toronto                                                     4
# East York                                                        4
# East TorontoBusiness reply mail Processing Centre969 Eastern     1
# Queen's Park                                                     1
# Downtown TorontoStn A PO Boxes25 The Esplanade                   1
# East YorkEast Toronto                                            1
# MississaugaCanada Post Gateway Processing Centre                 1
# EtobicokeNorthwest                                               1
# Name: borough, dtype: int64

# %%
Toronto.postal_code.value_counts()
# Out:
# M3G    1
# M7P    1
# M4C    1
# M4T    1
# M8T    1
#       ..
# M9R    1
# M2T    1
# M3X    1
# M5A    1
# M9Z    1
# Name: postal_code, Length: 180, dtype: int64

# %% [markdown]
# Remove from dataframe the values with 'Not assigened'

# %%
Toronto = Toronto[Toronto.borough != 'Not assigned']

# %%
Toronto = Toronto.reset_index(drop=True)

# %%
Toronto
# Out:
#     postal_code                                            borough  \
# 0           M3A                                         North York
# 1           M4A                                         North York
# 2           M5A                                   Downtown Toronto
# 3           M6A                                         North York
# 4           M7A                                       Queen's Park
# ..          ...                                                ...
# 98          M8X                                          Etobicoke
# 99          M4Y                                   Downtown Toronto
# 100         M7Y  East TorontoBusiness reply mail Processing Cen...
# 101         M8Y                                          Etobicoke
# 102         M8Z                                          Etobicoke
#
#                                         neighbourhoods
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                           Regent Park , Harbourfront
# 3                    Lawrence Manor , Lawrence Heights
# 4                        Ontario Provincial Government
# ..                                                 ...
# 98     The Kingsway , Montgomery Road , Old Mill North
# 99                                Church and Wellesley
# 100                                     Enclave of M4L
# 101  Old Mill South , King's Mill Park , Sunnylea ,...
# 102  Mimico NW , The Queensway West , South of Bloo...
#
# [103 rows x 3 columns]

# %% [markdown]
# These are the boroughs that have an invalid name, and they are corrected

# %%
Toronto['borough'].replace({'EtobicokeNorthwest': 'Etobicoke Northwest','East YorkEast Toronto':'East York','MississaugaCanada Post Gateway Processing Centre': 'Mississauga','East TorontoBusiness reply mail Processing Centre969 Eastern':'East Toronto','Downtown TorontoStn A PO Boxes25 The Esplanade':'Downtown Toronto'}, inplace=True)

# %%
Toronto.borough.value_counts()
# Out:
# North York             24
# Downtown Toronto       18
# Scarborough            17
# Etobicoke              11
# Central Toronto         9
# West Toronto            6
# East Toronto            5
# York                    5
# East York               5
# Queen's Park            1
# Etobicoke Northwest     1
# Mississauga             1
# Name: borough, dtype: int64

# %%
Toronto
# Out:
#     postal_code           borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A      Queen's Park
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                         neighbourhoods
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                           Regent Park , Harbourfront
# 3                    Lawrence Manor , Lawrence Heights
# 4                        Ontario Provincial Government
# ..                                                 ...
# 98     The Kingsway , Montgomery Road , Old Mill North
# 99                                Church and Wellesley
# 100                                     Enclave of M4L
# 101  Old Mill South , King's Mill Park , Sunnylea ,...
# 102  Mimico NW , The Queensway West , South of Bloo...
#
# [103 rows x 3 columns]

# %%
Toronto.shape
# Out:
# (103, 3)

# %% [markdown]
# ## Geolocate the Postal codes , getting the latitude and Longitude

# %%
addresses = list(Toronto['postal_code'])
lat=[]
lon=[]
for code in addresses:
    location = geolocate(code +', Toronto , Ontario')
    lat.append(location[0])
    lon.append(location[1])
Toronto['latitude']  = lat
Toronto['longitude'] = lon

# %%
Toronto.sort_values('longitude').head(30)
# Out:
#     postal_code              borough  \
# 89          M9V            Etobicoke
# 94          M9W  Etobicoke Northwest
# 17          M9C            Etobicoke
# 77          M9R            Etobicoke
# 50          M9L           North York
# 11          M9B            Etobicoke
# 93          M8W            Etobicoke
# 57          M9M           North York
# 70          M9P            Etobicoke
# 5           M9A            Etobicoke
# 102         M8Z            Etobicoke
# 60          M3N           North York
# 64          M9N                 York
# 46          M3L           North York
# 98          M8X            Etobicoke
# 53          M3M           North York
# 88          M8V            Etobicoke
# 101         M8Y            Etobicoke
# 49          M6L           North York
# 34          M3J           North York
# 56          M6M                 York
# 63          M6N                 York
# 81          M6S         West Toronto
# 40          M3K           North York
# 69          M6P         West Toronto
# 21          M6E                 York
# 3           M6A           North York
# 75          M6R         West Toronto
# 28          M3H           North York
# 10          M6B           North York
#
#                                         neighbourhoods  latitude  longitude
# 89   South Steeles , Silverstone , Humbergate , Jam...  43.74453  -79.58624
# 94   Clairville , Humberwood , Woodbine Downs , Wes...  43.71174  -79.57941
# 17   Eringate , Bloordale Gardens , Old Burnhamthor...  43.64857  -79.57825
# 77   Kingsview Village , St. Phillips , Martin Grov...  43.68681  -79.55728
# 50                                       Humber Summit  43.75948  -79.55707
# 11   West Deane Park , Princess Gardens , Martin Gr...  43.65034  -79.55362
# 93                             Alderwood , Long Branch  43.60124  -79.53879
# 57                                   Humberlea , Emery  43.73367  -79.53769
# 70                                           Westmount  43.69630  -79.52926
# 5                                     Islington Avenue  43.66263  -79.52831
# 102  Mimico NW , The Queensway West , South of Bloo...  43.62513  -79.52681
# 60                                  DownsviewNorthwest  43.75478  -79.51959
# 64                                              Weston  43.70507  -79.51804
# 46                                       DownsviewWest  43.72071  -79.51701
# 98     The Kingsway , Montgomery Road , Old Mill North  43.65319  -79.51113
# 53                                    DownsviewCentral  43.73224  -79.50178
# 88      New Toronto , Mimico South , Humber Bay Shores  43.60987  -79.49809
# 101  Old Mill South , King's Mill Park , Sunnylea ,...  43.63278  -79.48945
# 49          North Park , Maple Leaf Park , Upwood Park  43.71381  -79.48874
# 34                    Northwood Park , York University  43.76476  -79.48798
# 56   Del Ray , Mount Dennis , Keelsdale and Silvert...  43.69517  -79.48397
# 63                      Runnymede , The Junction North  43.67646  -79.48272
# 81                                 Runnymede , Swansea  43.64982  -79.47548
# 40                           DownsviewEast CFB Toronto  43.73384  -79.46828
# 69                      High Park , The Junction South  43.65973  -79.46281
# 21                                 Caledonia-Fairbanks  43.68784  -79.45046
# 3                    Lawrence Manor , Lawrence Heights  43.72327  -79.45042
# 75                             Parkdale , Roncesvalles  43.64777  -79.44989
# 28   Bathurst Manor , Wilson Heights , Downsview North  43.75788  -79.44847
# 10                                           Glencairn  43.70687  -79.44812

# %%
Toronto.borough.value_counts()
# Out:
# North York             24
# Downtown Toronto       18
# Scarborough            17
# Etobicoke              11
# Central Toronto         9
# West Toronto            6
# East Toronto            5
# York                    5
# East York               5
# Queen's Park            1
# Etobicoke Northwest     1
# Mississauga             1
# Name: borough, dtype: int64

# %% [markdown]
# ## MAP of Toronto with Boroughs/Postal Codes

# %%
city = 'Toronto, Ontario'

coords = geolocate(city)
latitude_tor = coords[0]
longitude_tor = coords[1]

# %%
print('The geograpical coordinate of {} are {}, {}.'.format(city, latitude_tor, longitude_tor))
# Out:
# The geograpical coordinate of Toronto, Ontario are 43.648690000000045, -79.38543999999996.

# %%
map_toronto = folium.Map(location=[latitude_tor, longitude_tor], zoom_start=10)

# %%
for lat, lng, borough, neighborhood in zip(Toronto['latitude'], Toronto['longitude'], Toronto['borough'], Toronto['neighbourhoods']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)

# %%
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_f44a161b4595471f95d26693554096e5%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f44a161b4595471f95d26693554096e5%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f44a161b4595471f95d26693554096e5%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_f44a161b4595471f95d26693554096e5%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.648690000000045%2C-79.38543999999996%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%2 ...

# %%
Toronto
# Out:
#     postal_code           borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A      Queen's Park
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                         neighbourhoods  latitude  longitude
# 0                                            Parkwoods  43.75245  -79.32991
# 1                                     Victoria Village  43.73057  -79.31306
# 2                           Regent Park , Harbourfront  43.65512  -79.36264
# 3                    Lawrence Manor , Lawrence Heights  43.72327  -79.45042
# 4                        Ontario Provincial Government  43.66253  -79.39188
# ..                                                 ...       ...        ...
# 98     The Kingsway , Montgomery Road , Old Mill North  43.65319  -79.51113
# 99                                Church and Wellesley  43.66659  -79.38133
# 100                                     Enclave of M4L  43.64869  -79.38544
# 101  Old Mill South , King's Mill Park , Sunnylea ,...  43.63278  -79.48945
# 102  Mimico NW , The Queensway West , South of Bloo...  43.62513  -79.52681
#
# [103 rows x 5 columns]

# %%
Toronto.shape
# Out:
# (103, 5)
